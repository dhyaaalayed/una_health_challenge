# %%
import pandas as pd

# %%
df1 = pd.read_csv("aaaaaaaa-aaaa-aaaa-aaaa-aaaaaaaaaaaa.csv", skiprows=[0])

# %%
df1["user_id"] = "aaaaaaaa-aaaa-aaaa-aaaa-aaaaaaaaaaaa"

# %%
df1
# Out:
#                     Gerät                          Seriennummer  \
# 0     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 2     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 3     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 4     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# ...                   ...                                   ...
# 1194  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1195  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1196  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1197  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1198  FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
#
#      Gerätezeitstempel  Aufzeichnungstyp  Glukosewert-Verlauf mg/dL  \
# 0     18-02-2021 10:57                 0                       77.0
# ...

# %%
df2 = pd.read_csv("bbbbbbbb-bbbb-bbbb-bbbb-bbbbbbbbbbbb.csv", skiprows=[0])
df2["user_id"] = "bbbbbbbb-bbbb-bbbb-bbbb-bbbbbbbbbbbb"

# %%
df2
# Out:
#                     Gerät                          Seriennummer  \
# 0     FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 1     FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 2     FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 3     FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 4     FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# ...                   ...                                   ...
# 1364  FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 1365  FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 1366  FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 1367  FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
# 1368  FreeStyle LibreLink  006A3043-6E08-4C19-B3F1-B0D95C5737CA
#
#      Gerätezeitstempel  Aufzeichnungstyp  Glukosewert-Verlauf mg/dL  \
# 0     18-02-2021 11:19                 0                       97.0
# ...

# %%
df3 = pd.read_csv("cccccccc-cccc-cccc-cccc-cccccccccccc.csv", skiprows=[0])
df3["user_id"] = "cccccccc-cccc-cccc-cccc-cccccccccccc"

# %%
df3
# Out:
#                     Gerät                          Seriennummer  \
# 0     FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 1     FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 2     FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3     FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 4     FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# ...                   ...                                   ...
# 1418  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 1419  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 1420  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 1421  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 1422  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
#
#      Gerätezeitstempel  Aufzeichnungstyp  Glukosewert-Verlauf mg/dL  \
# 0     10-02-2021 09:08                 0                      138.0
# ...

# %%
df = pd.concat([df1, df2,df3]).reset_index(drop=True)

# %%
df
# Out:
#                     Gerät                          Seriennummer  \
# 0     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 2     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 3     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 4     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# ...                   ...                                   ...
# 3986  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3987  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3988  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3989  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3990  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
#
#      Gerätezeitstempel  Aufzeichnungstyp  Glukosewert-Verlauf mg/dL  \
# 0     18-02-2021 10:57                 0                       77.0
# ...

# %%
df["id"] = df.index

# %%
df
# Out:
#                     Gerät                          Seriennummer  \
# 0     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 2     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 3     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 4     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# ...                   ...                                   ...
# 3986  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3987  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3988  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3989  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3990  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
#
#      Gerätezeitstempel  Aufzeichnungstyp  Glukosewert-Verlauf mg/dL  \
# 0     18-02-2021 10:57                 0                       77.0
# ...

# %%
df = df.dropna(axis=1, how='all')

# %%
df
# Out:
#                     Gerät                          Seriennummer  \
# 0     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 1     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 2     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 3     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# 4     FreeStyle LibreLink  1D48A10E-DDFB-4888-8158-026F08814832
# ...                   ...                                   ...
# 3986  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3987  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3988  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3989  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
# 3990  FreeStyle LibreLink  e09bb0f0-018b-429b-94c7-62bb306a0136
#
#      Gerätezeitstempel  Aufzeichnungstyp  Glukosewert-Verlauf mg/dL  \
# 0     18-02-2021 10:57                 0                       77.0
# ...

# %%
df.to_csv("all_data.csv", index = False)
